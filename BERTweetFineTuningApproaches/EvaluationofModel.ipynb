# %%
pip install transformers datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
pip install huggingface_hub

# %%
from huggingface_hub import login

# Paste your token here
login(token="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")

# %%
from huggingface_hub import HfApi, HfFolder, create_repo, upload_folder

# Replace with your Hugging Face username and desired repo name
repo_id = "Himaparasa/bertweet-sentiment-model"

# Authenticate
api = HfApi()
token = HfFolder.get_token()

# Create the repository on Hugging Face Hub
repo_url = create_repo(repo_id=repo_id, token=token, exist_ok=True)

# Upload the model folder to the repository
upload_folder(
    folder_path=model_dir,
    path_in_repo="",
    repo_id=repo_id,
    token=token,
)
print(f"Model uploaded to {repo_url}")
# Out:
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Model uploaded to https://huggingface.co/Himaparasa/bertweet-sentiment-model

# %%
pip install transformers huggingface_hub

# %%
from transformers import pipeline

# Load the model from Hugging Face
pipe = pipeline("text-classification", model="Himaparasa/bertweet-sentiment-model")

# Test with sample text
text = "I absolutely love this product!"
result = pipe(text)
print(result)
# Out:
# config.json:   0%|          | 0.00/977 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# [{'label': 'POS', 'score': 0.992601215839386}]

# %%
# List of sentences to test
texts = [
    "Feeling goalorious today—it's that glorious vibe you get when you're crushing goals and loving the journey.",
    "Love how my emails are 'urgent,' but your replies are 'when convenient.",
    "Honestly, I don’t know if I’m vibing with this whole situation, it’s kind of a distrapocalypse like, everything’s falling apart but in the most oddly captivating way, you know?",
    "Ugh, this is so cringe-worthy- I can’t even deal with it anymore.",
    "That terrible take got ratioed in less than 10 minutes. People aren't holding back today",
    "Oh, fantastic—another day of procrastinating my life away while mentalbouncing through endless taskflation. Truly, I’m living the dream.",
    "My culture budget's looking kinda sus this month; rent's a whole vibe killer,  but at least I can still slay my fits",
    "OMG, my bio project's crispr-ed,  like, totally fixed my messed-up DNA—it's giving chef's kiss.",
    "Despite the market volatility,  my defi investments are surprisingly stable, offering a compelling alternative to traditional finance.",
    "Despite the hefty price tag, carbon capture technology offers a crucial, albeit imperfect, solution to rising atmospheric CO2 levels.",

]

# Get predictions for all texts
results = pipe(texts)

# Display predictions
for text, sentiment in zip(texts, results):
    print(f"Text: {text}\nPrediction: {sentiment}\n")
# Out:
# Text: Feeling goalorious today—it's that glorious vibe you get when you're crushing goals and loving the journey.
# Prediction: {'label': 'POS', 'score': 0.991981565952301}
#
# Text: Love how my emails are 'urgent,' but your replies are 'when convenient.
# Prediction: {'label': 'POS', 'score': 0.9846712946891785}
#
# Text: Honestly, I don’t know if I’m vibing with this whole situation, it’s kind of a distrapocalypse like, everything’s falling apart but in the most oddly captivating way, you know?
# Prediction: {'label': 'NEG', 'score': 0.9159004092216492}
#
# Text: Ugh, this is so cringe-worthy- I can’t even deal with it anymore.
# Prediction: {'label': 'NEG', 'score': 0.98260498046875}
#
# Text: That terrible take got ratioed in less than 10 minutes. People aren't holding back today
# Prediction: {'label': 'NEG', 'score': 0.9750716686248779}
#
# ...
