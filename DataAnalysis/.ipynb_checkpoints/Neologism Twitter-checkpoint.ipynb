# %% [markdown]
# # Authored by
# This notebook was authored by **Priyadarshini Tamilselvan**

# %%
import pandas as pd

twitter_df = pd.read_csv('raw_tweets_text.csv')

print("Dataset preview:")
print(twitter_df.head())

print("Column names:")
print(twitter_df.columns)
# Out:
# Dataset preview:
#                    id                                               text
# 0  758014713804587008  RT @polarcomic: And surprise! the #RegularShow...
# 1  758014717990428672  RT @SweetBabyBellB: My unproblematic fav who k...
# 2  758014646716665857  RT @WhyLarryIsReal: I mean we know harry isn't...
# 3  758014655071526912  RT @Eastbay: She's ready, resilient, and on ou...
# 4  758014642526429184  RT @SheeeRatchet: find someone who loves you a...
# Column names:
# Index(['id', 'text'], dtype='object')

# %%
neologism_words = pd.read_csv('Neologisms.csv')

print("Dataset preview:")
print(neologism_words.head())

print("Column names:")
print(neologism_words.columns)

values = ['handpicked', 'dictionary']
filtered_df_n = neologism_words[~neologism_words['Source'].isin(values)]

words_to_find = filtered_df_n.Neologism
words_set = set(words_to_find.str.lower())
# Out:
# Dataset preview:
#      Neologism                          Note Source Classification  \
# 0           cx           customer experience   news        lexical
# 1       crispr                           NaN   news        lexical
# 2         defi         decentralized finance   news  morphological
# 3         oled  organic light emitting diode   news        lexical
# 4  longtermism                           NaN   news  morphological
#
#      Subcategory                date
# 0        acronym  2018-03-01 0:00:00
# 1        acronym  2017-02-01 0:00:00
# 2  partial blend  2021-11-01 0:00:00
# 3        acronym  2021-10-01 0:00:00
# 4          blend  2022-08-01 0:00:00
# Column names:
# Index(['Neologism', 'Note', 'Source', 'Classification', 'Subcategory', 'date'], dtype='object')

# %%
def find_words(text):
    words_in_text = set(str(text).lower().split())  # Tokenize and lowercase the text
    return words_set.intersection(words_in_text)

# %%
twitter_df['found_words'] = twitter_df.text.fillna('').apply(find_words)

all_found_words = set().union(*twitter_df['found_words'])
print("All unique words found in the dataset:")
print(all_found_words)
# Out:
# All unique words found in the dataset:
# {'oystering', 'rideshare', 'numerology', 'beneficiaries', 'dm', 'redistricting', 'bioluminescent', 'plumping', 'democraps', 'fnf', 'todger', 'disassociate', 'gatekeeper', 'digitalization', 'ilyt', 'microblading', 'e-gift', 'dermaplaning', 'cummies', 'disinflation', 'languishing', 'hyperlexia', 'insurtech', 'nvme', 'esg', 'doxxing', 'nft', 'woke', 'reopened', 'mandates', 'wanderlust', 'abound', '459', 'lamination', 'severance', 'romanced', 'scourer', 'pickme', 'turnd', 'bodycam', 'hagakure', 'widget', 'twin-turbo', 'whitewash', 'pre-t', 'neurodiversity', 'weaponization', 'dropshipping', 'mezcal', 'sweatpant', 'whelmed', 'asbestosis', 'floofy', 'thrifting', 'liveable', 'paywall', 'misogynoir', 'ghosting', 'bingsu', 'nlg', 'inclusivity', 'thd', 'overreacting', 'elopement', 'wcq', 'ggl', 'wtv', 'wyd', 'minicab', 'rollups', 'single-use', 'wakanda', 'vibing', 'yimby', 'vaxxed', 'instagrammer', 'boomer', '5head', 'first-person', 'jwt', 'dnf', 'roty', 'ody', 'cavitation', 'volatility', 'mansplaining', 'sheesh', 'femicide', 'dei', 'bpd', 'abseiling', 'omds', 'shuffled', 'gamify', 'undershirt', 'oshi', 'defunded', 'quarantine', 'mobilization', 'retrograde', 'intersectionality', 'niches', 'strongwoman', 'peptides', 'trade-in', 'ndr', 'hsr', 'bnbs', 'telemedicine', 'car-t', 'e-mobility', 'long-term', 'prenup', 'wokeness', 'agm', 'hogging', 'insta-block', 'teargassed', 'mbn', 'zesty', 'boober', 'microplastics', 'pickleball', 'gcses', 'anti-bds', 'problematic', 'flexitarian', 'metaverse', 'drippy', 'abrosexual', 'biphobic', 'virality', 'twee', 'regen', 'crawdad', 'goldleaf', 'nil', 'skincare', 'pentesting', 'scabbing', 'staking', 'weirding', 'defrauding', 'variants', 'cashless', 'eicr', 'phe', 'highlevel', 'bulked', 'prediabetes', 'xdr', 'slowed', 'manifestation', 'pre-entry', 'omicron', 'civet', 'biohack', 'birthrights', 'unbanned', 'offloading', 'gentrified', 'waf', 'blm', 'facepiece', 'teetee', 'moisture-wicking', 'emom', 'nonporous', 'fact-checking', 'psyop', 'gents', 'hellfire', 'infinitude', 'chatbot', 'lionesses', 'projekt', 'cancellation', 'crispr', 'enby', 'lovebugs', 'kingmaker', 'high-fiber', 'locally-sourced', 'vpns', 'permitless', 'tbagging', 'grifter', 'clowned', '2fa', 'squatted', 'restrictions', 'ocpd', 'reinstated', 'whiteness', 'crypto', 'shitass', 'defi', 'deshed', 'pcos', 'gummies', 'maximalism', 'detangling', 'abg', 'gock', 'gpu', 'dumpy', 'cisgender', 'conservatorship', 'slayyyy', 'ecr', 'high-risk', 'dysphoria', 'fearmongering', 'gaslighting', 'thriving', 'preregister', 'slutshamed', 'braincells', 'multiverse', 'fintech', 'sheeee', 'terf', 'fasting', 'esting', 'spac', 'antifascist', 'brutalism', 'nonbinary', 'touchless', 'event-driven', 'co-investment', 'tankie', 'nonwoven', 'hbcu', 'mof', 'pmv', 'transitory', 'dupe', 'riots', 's3xy', 'pull-on', 'scif', 'hcq', 'magis', 'fizzling', 'confirmed', 'latinx', 'endemic', 'indictments', 'bingewatch', 'twunk', 'unbanked', 'yummers', 'wtm', 'bioactive', 'minidress', 'yt', 'sterilisation', 'antitrans', 'gilts', 'illiberal', 'softboy', 'jugging', 'supersoft', 'vers', 'trolled', 'b2a', 'istfg', 'manifest', '5g', 'interlining', 'oppar', 'perms', 'findom', 'beaut', 'wholefood', 'sextile', 'fie', 'rickroll', 'fandom', 'apprenticeships', 'deferral', 'bookish', 'self-employed', 'backend', 'delist', 'roguelike', 'oligarchs', 'fancams', 'skimming', 'headie', 'freediving', 'overshirt', 'streamers', 'podracer', 'stitch', 'telehealth', 'idfk', 'anti', 'pii', 'freshie', 'systemic', 'teargas', 'bloke', 'anti-racism', 'staycation', 'lyocell', 'derailment', 'dbt', 'erudition', 'decarbonization', 'borg', 'plushies', 'shiet', 'bulking', 'whitewashed', 'edating', 'overturning', 'volumizing', 'liming', 'boundaries', 'unserious', 'tcg', 'transphobic', 'slurs', 'blw', 'gen-z', 'homegirl', 'tightener', 'sped', 'situationship', 'bullish', 'afk', 'convo', 'whipped', 'loat', 'phygital', 'sanctions', 'fullstack', 'paraprofessionals', 'ableist', 'baijiu', 'monochrome', 'freestanding', 'wholesome', 'bucked' ...

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count the frequency of each found word across all rows
all_found_words = [word for words in twitter_df['found_words'] for word in words]
word_counts = Counter(all_found_words)

# Convert to two lists for plotting
words, counts = zip(*word_counts.most_common(20))  # Top 20 most common words

# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Top 20 Most Frequent Words Found in the Reddit Dataset")
plt.show()

# %%
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_counts)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Twitter Neologism Words")
plt.show()

# %%
neologism_words2 = pd.read_csv('Inputs.csv')

print("Dataset preview:")
print(neologism_words2.head())

print("Column names:")
print(neologism_words2.columns)

words_to_find = neologism_words2.Neologism
words_set = set(words_to_find.str.lower())
# Out:
# Dataset preview:
#           Neologism             What Is Question  \
# 0    stay interview    What is a stay interview?
# 1     skin kindness       What is skin kindness?
# 2  cyber risk score  What is a cyber risk score?
# 3        angel shot       What is an angel shot?
# 4      greenwashing        What is greenwashing?
#
#                                           Definition Copy Penalty (MT)  Type  \
# 0  A stay interview is an interview or, more like...               Yes  news
# 1  Skin kindness is a new skincare trend that foc...               Yes  news
# 2  A cyber risk score is a numerical assessment o...               Yes  news
# 3  An angel shot is a drink order made by a custo...               Yes  news
# 4  Greenwashing is the act or practice of making ...               Yes  news
#
#   Linguistic Type Linguistic Subcategory                Date  \
# 0        semantic             substitute  2022-01-01 0:00:00
# 1         lexical             new phrase  2021-10-01 0:00:00
# 2         lexical             new phrase             No Date
# 3         lexical             new phrase  2022-07-01 0:00:00
# 4   morphological                  blend  2022-02-01 0:00:00
#
#                              Minimal Pair Sentence 1  \
# 0  A short, informal conversation between an empl...
# 1  Skin kindness is a new skincare trend that foc...
# 2  To mitigate the potential danger of digital th...
# 3  While not a shot or a drink, a code that sends...
# 4  Greenwashing involves making an unsubstantiate...
#
#                              Minimal Pair Sentence 2  ... Unnamed: 23  \
# 0  A short, informal conversation between an empl...  ...         NaN
# 1  Gentle skin cleanser is a new skincare trend t...  ...         NaN
# 2  To mitigate the potential danger of digital th...  ...         NaN
# 3  While not a shot or a drink, a code that sends...  ...         NaN
# 4  Misinformation involves making an unsubstantia...  ...         NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 33 columns]
# Column names:
# Index(['Neologism', 'What Is Question', 'Definition', 'Copy Penalty (MT)',
#        'Type', 'Linguistic Type', 'Linguistic Subcategory', 'Date',
#        'Minimal Pair Sentence 1', 'Minimal Pair Sentence 2', 'Source',
#        'CLOZE Sentence 1', 'CLOZE Sentence 2', 'Alternative Correct Answer',
#        'Answer 1', 'Answer 2', 'Answer 3', 'Answer 4', 'Answer 5', 'Source.1',
#        'Comments', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
twitter_df['found_words_2'] = twitter_df.text.fillna('').apply(find_words)

all_found_words = set().union(*twitter_df['found_words_2'])
print("All unique words found in the dataset:")
print(all_found_words)
# Out:
# All unique words found in the dataset:
# {'deferral', 'oystering', 'bookish', 'plumping', 'beneficiaries', 'roguelike', 'oligarchs', 'fnf', 'todger', 'disassociate', 'disinflation', 'languishing', 'overshirt', 'streamers', 'nvme', 'snowvember', 'facepiece', 'nft', 'woke', 'mandates', 'telehealth', 'wanderlust', 'wdy', 'llm', 'anti', 'freshie', 'bodycam', 'hagakure', 'teargas', 'bloke', 'anti-racism', 'systemic', 'mezcal', 'dbt', 'dropshipping', 'decarbonization', 'edating', 'asbestosis', 'volumizing', 'liming', 'floofy', 'tcg', 'slurs', 'blw', 'bullish', 'whipped', 'nlg', 'phygital', 'overreacting', 'wcq', 'fullstack', 'ggl', 'wtv', 'rollups', 'single-use', 'yimby', 'vibing', 'bucked', 'papr', 'instagrammer', 'first-person', 'jwt', 'criminalize', 'cx', 'volatility', 'mansplaining', 'sheesh', 'femicide', 'inbred', 'organoids', 'omds', 'defunded', 'chessboxing', 'quarantine', 'doubling', 'testing', 'vishing', 'bougie', 'intersectionality', 'copyrighted', 'hsr', 'uninviting', 'interfacing', 'telemedicine', 'long-term', 'wokeness', 'finsta', 'hogging', 'mbn', 'nonce', 'boober', 'microplastics', 'kpi', 'anti-racist', 'jutsu', 'problematic', 'metaverse', 'drippy', 'tibs', 'real', 'disinformation', 'donning', 'haptics', 'icing', 'ivr', 'pentesting', 'staking', 'downbad', 'weirding', 'variants', 'refundable', 'e-girl', 'eicr', 'bot', 'prediabetes', 'oled', 'blud', 'misgendering', 'slowed', 'manifestation', 'omicron', 'civet', 'birthrights', 'blm', 'psyop', 'unvaccinated', 'hellfire', 'callboy', 'infinitude', 'lionesses', 'projekt', 'crispr', 'longwear', 'mald', 'bestie', 'madge', 'permitless', 'grifter', 'kwh', 'squatted', 'restrictions', 'webinar', 'whiteness', 'babymomma', 'hydrosphere', 'defi', 'stagflation', 'dissociate', 'deshed', 'webseries', 'detangling', 'rizz', 'agaric', 'toxic', 'metamaterials', 'cisgender', 'conservatorship', 'slayyyy', 'high-risk', 'dysphoria', 'fearmongering', 'gaslighting', 'preregister', 'under-eye', 'anti-black', 'sheeee', 'touchless', 'spac', 'antifascist', 'satiety', 'nonbinary', 'gaiters', 'egfr', 'waterblock', 'voming', 'ots', '6-piece', 'mid', 'nonwoven', 'transitory', 'dupe', 'queerbaiting', 'endemic', 'latinx', 'twunk', 'based', 'bioactive', 'yt', 'antitrans', 'upskill', 'codify', 'softboy', 'handwashing', 'shash', 'vers', 'b2a', 'wans', 'pretext', 'self-sabotage', 'oppar', 'mooc', 'findom', 'wholefood', 'fie'}

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count the frequency of each found word across all rows
all_found_words = [word for words in twitter_df['found_words_2'] for word in words]
word_counts = Counter(all_found_words)

# Convert to two lists for plotting
words, counts = zip(*word_counts.most_common(20))  # Top 20 most common words

# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Top 20 Most Frequent Words Found in the Reddit Dataset")
plt.show()

# %%
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_counts)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Found Words")
plt.show()
